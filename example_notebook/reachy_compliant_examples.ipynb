# %%
# Importing necessary libraries

from reachy_sdk_modified import ReachySDK
import numpy as np

from reachy_sdk_modified.trajectory import goto_compliant
from reachy_sdk_modified.trajectory import InterpolationMode
import time

# %%
# Only needed for simulation

import subprocess

# %%
def happy_antennas():
    for _ in range(7):
        reachy.head.l_antenna.goal_position = 30.0
        reachy.head.r_antenna.goal_position = -30.0

        time.sleep(0.2)

        reachy.head.l_antenna.goal_position = -30.0
        reachy.head.r_antenna.goal_position = 30.0

        time.sleep(0.2)

    reachy.head.l_antenna.goal_position = 0.0
    reachy.head.r_antenna.goal_position = 0.0

# %%
def hello_left_arm():
    left_arm_hello_position = {
    reachy.l_arm.l_shoulder_pitch: 0,
    reachy.l_arm.l_shoulder_roll: 50,
    reachy.l_arm.l_arm_yaw: 70,
    reachy.l_arm.l_elbow_pitch: -120,
    reachy.l_arm.l_forearm_yaw: 80,
    reachy.l_arm.l_wrist_pitch: 0,
    reachy.l_arm.l_wrist_roll: -40,
    }

    left_arm_base_position = {
    reachy.l_arm.l_shoulder_pitch: 0,
    reachy.l_arm.l_shoulder_roll: 0,
    reachy.l_arm.l_arm_yaw: 0,
    reachy.l_arm.l_elbow_pitch: 0,
    reachy.l_arm.l_forearm_yaw: 0,
    reachy.l_arm.l_wrist_pitch: 0,
    reachy.l_arm.l_wrist_roll: 0,
    }
    
    # The 'goto_compliant' function is exactly like the goto function, except it takes two additional inputs
    
    goto_compliant(
    goal_positions = left_arm_hello_position,
    damping_matrix = np.identity(len(left_arm_hello_position)),
    stiffness_matrix = np.identity(len(left_arm_hello_position)),
    duration = 5,
    interpolation_mode = InterpolationMode.MINIMUM_JERK
    )

    for _ in range(3):
        goto_compliant(
          goal_positions = {reachy.l_arm.l_wrist_roll: 20.0},
          damping_matrix = np.identity(1),
          stiffness_matrix = np.identity(1),
          duration = 1.5,
          interpolation_mode = InterpolationMode.LINEAR
        )
        goto_compliant(
          goal_positions = {reachy.l_arm.l_wrist_roll: -40.0},
          damping_matrix = np.identity(1),
          stiffness_matrix = np.identity(1),
          duration = 1.5,
          interpolation_mode = InterpolationMode.LINEAR
        )

    time.sleep(0.2)

    goto_compliant(
    goal_positions = left_arm_base_position,
    damping_matrix = np.identity(len(left_arm_base_position)),
    stiffness_matrix = np.identity(len(left_arm_base_position)),
    duration = 5,
    interpolation_mode = InterpolationMode.LINEAR
    )

# %%
def move_head():
    reachy.head.look_at(0.5, -0.3, -0.1, duration=1.0)
    time.sleep(0.3)
    reachy.head.look_at(0.5, 0.3, -0.1, duration=1.0)
    time.sleep(0.3)
    reachy.head.look_at(0.5, 0, -0.1, duration=1.0)
    time.sleep(0.3)
    
    head_tilted_position = {
    reachy.head.neck_roll: -20,
    reachy.head.neck_pitch: 0,
    reachy.head.neck_yaw:0,
    }
    
    goto_compliant(
    damping_matrix = np.identity(len(head_tilted_position)),
    stiffness_matrix = np.identity(len(head_tilted_position)),
    goal_positions = head_tilted_position,
    duration = 1,
    interpolation_mode = InterpolationMode.MINIMUM_JERK
    )

# %%
def say_hello():
    #move_head()
    happy_antennas()
    hello_left_arm()
    #reachy.head.look_at(0.5, 0, 0, duration=0.5)

# %%
def get_localhost_wsl():
    result = subprocess.check_output("cat /etc/resolv.conf | grep nameserver | awk '{ print $2 }'", shell=True, text=True)
    result = result[:-1]
    print(result)
    return result

# %%
# First, run Windows Powershell as an administrator, and run the following command:
# New-NetFirewallRule -DisplayName "WSL" -Direction Inbound  -InterfaceAlias "vEthernet (WSL)"  -Action Allow
# reachy = ReachySDK(host='localhost') # replace with correct IP if the simulation is not on your computer
# reachy = ReachySDK(host='Acer-Nitro-5.local') # Find IP in WSL by running 'ip route' command in the terminal, and looking for the 'default via' value
  
ip_address = get_localhost_wsl()
reachy = ReachySDK(host=ip_address) # Find IP in WSL by running 'ip route' command in the terminal, and looking for the 'default via' value
say_hello()
# Out:
# 172.25.0.1
# Entering goto function for modified library
# Goal Positions:  {<Joint name="l_shoulder_pitch" pos="1.26" mode="stiff">: 0, <Joint name="l_shoulder_roll" pos="3.54" mode="stiff">: 50, <Joint name="l_arm_yaw" pos="-2.88" mode="stiff">: 70, <Joint name="l_elbow_pitch" pos="-1.03" mode="stiff">: -120, <Joint name="l_forearm_yaw" pos="-1.20" mode="stiff">: 80, <Joint name="l_wrist_pitch" pos="2.53" mode="stiff">: 0, <Joint name="l_wrist_roll" pos="-2.28" mode="stiff">: -40}
# Goal Positions Keys:  [<Joint name="l_shoulder_pitch" pos="1.26" mode="stiff">, <Joint name="l_shoulder_roll" pos="3.54" mode="stiff">, <Joint name="l_arm_yaw" pos="-2.88" mode="stiff">, <Joint name="l_elbow_pitch" pos="-1.03" mode="stiff">, <Joint name="l_forearm_yaw" pos="-1.20" mode="stiff">, <Joint name="l_wrist_pitch" pos="2.53" mode="stiff">, <Joint name="l_wrist_roll" pos="-2.28" mode="stiff">]
# Joint List:  ['l_shoulder_pitch', 'l_shoulder_roll', 'l_arm_yaw', 'l_elbow_pitch', 'l_forearm_yaw', 'l_wrist_pitch', 'l_wrist_roll']
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Breaking
# elapsed_time 4.2158308029174805
# Goal Positions [   0   50   70 -120   80    0  -40]
# Final Position:  [   1.17   51.17   65.45 -117.07   76.58    2.11  -40.48]
# Error:  4.549999999999997
# Change:  0.0
#
# Entering goto function for modified library
# Goal Positions:  {<Joint name="l_wrist_roll" pos="-40.48" mode="stiff">: 20.0}
# Goal Positions Keys:  [<Joint name="l_wrist_roll" pos="-40.48" mode="stiff">]
# Joint List:  ['l_wrist_roll']
# Breaking
# elapsed_time 1.5028667449951172
# Goal Positions [20.]
# Final Position:  [15.72]
# Error:  4.279999999999999
# Change:  0.0
#
# Entering goto function for modified library
# Goal Positions:  {<Joint name="l_wrist_roll" pos="15.72" mode="stiff">: -40.0}
# Goal Positions Keys:  [<Joint name="l_wrist_roll" pos="15.72" mode="stiff">]
# Joint List:  ['l_wrist_roll']
# Breaking
# elapsed_time 1.532743215560913
# Goal Positions [-40.]
# Final Position:  [-36.17]
# Error:  3.8299999999999983
# Change:  0.0
#
# Entering goto function for modified library
# Goal Positions:  {<Joint name="l_wrist_roll" pos="-38.01" mode="stiff">: 20.0}
# Goal Positions Keys:  [<Joint name="l_wrist_roll" pos="-38.01" mode="stiff">]
# Joint List:  ['l_wrist_roll']
# Breaking
# elapsed_time 1.5037181377410889
# Goal Positions [20.]
# Final Position:  [15.76]
# Error:  4.24
# Change:  0.0
#
# Entering goto function for modified library
# Goal Positions:  {<Joint name="l_wrist_roll" pos="16.63" mode="stiff">: -40.0}
# Goal Positions Keys:  [<Joint name="l_wrist_roll" pos="16.63" mode="stiff">]
# Joint List:  ['l_wrist_roll']
# Breaking
# elapsed_time 1.4964399337768555
# Goal Positions [-40.]
# Final Position:  [-36.04]
# Error:  3.960000000000001
# Change:  0.0
#
# Entering goto function for modified library
# Goal Positions:  {<Joint name="l_wrist_roll" pos="-36.04" mode="stiff">: 20.0}
# Goal Positions Keys:  [<Joint name="l_wrist_roll" pos="-36.04" mode="stiff">]
# Joint List:  ['l_wrist_roll']
# Breaking
# elapsed_time 1.5042390823364258
# Goal Positions [20.]
# Final Position:  [16.42]
# Error:  3.5799999999999983
# Change:  0.0
#
# Entering goto function for modified library
# Goal Positions:  {<Joint name="l_wrist_roll" pos="16.42" mode="stiff">: -40.0}
# Goal Positions Keys:  [<Joint name="l_wrist_roll" pos="16.42" mode="stiff">]
# Joint List:  ['l_wrist_roll']
# Breaking
# elapsed_time 1.5080232620239258
# Goal Positions [-40.]
# Final Position:  [-35.64]
# Error:  4.359999999999999
# Change:  0.0
#
# Entering goto function for modified library
# Goal Positions:  {<Joint name="l_shoulder_pitch" pos="0.81" mode="stiff">: 0, <Joint name="l_shoulder_roll" pos="50.87" mode="stiff">: 0, <Joint name="l_arm_yaw" pos="66.62" mode="stiff">: 0, <Joint name="l_elbow_pitch" pos="-117.83" mode="stiff">: 0, <Joint name="l_forearm_yaw" pos="77.49" mode="stiff">: 0, <Joint name="l_wrist_pitch" pos="1.61" mode="stiff">: 0, <Joint name="l_wrist_roll" pos="-39.79" mode="stiff">: 0}
# Goal Positions Keys:  [<Joint name="l_shoulder_pitch" pos="0.81" mode="stiff">, <Joint name="l_shoulder_roll" pos="50.87" mode="stiff">, <Joint name="l_arm_yaw" pos="66.62" mode="stiff">, <Joint name="l_elbow_pitch" pos="-117.83" mode="stiff">, <Joint name="l_forearm_yaw" pos="77.49" mode="stiff">, <Joint name="l_wrist_pitch" pos="1.61" mode="stiff">, <Joint name="l_wrist_roll" pos="-39.79" mode="stiff">]
# Joint List:  ['l_shoulder_pitch', 'l_shoulder_roll', 'l_arm_yaw', 'l_elbow_pitch', 'l_forearm_yaw', 'l_wrist_pitch', 'l_wrist_roll']
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Breaking
# elapsed_time 4.779758930206299
# Goal Positions [0 0 0 0 0 0 0]
# Final Position:  [ 1.78  4.8  -3.79 -1.58 -1.55  3.42 -3.06]
# Error:  4.8
# Change:  0.0
# Exception in thread Thread-5 (_start_sync_in_bg):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.10/threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/d/coding_stuff/reachy-sdk-modified/reachy_sdk_modified/reachy_sdk.py", line 203, in _start_sync_in_bg
#     loop.run_until_complete(self._sync_loop())
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 646, in run_until_complete
#     return future.result()
#   File "/mnt/d/coding_stuff/reachy-sdk-modified/reachy_sdk_modified/reachy_sdk.py", line 258, in _sync_loop
#     await asyncio.gather(
#   File "/mnt/d/coding_stuff/reachy-sdk-modified/reachy_sdk_modified/reachy_sdk.py", line 247, in _stream_commands_loop
#     await joint_stub.StreamJointsCommands(command_poll())
#   File "/home/danyal/.local/lib/python3.10/site-packages/grpc/aio/_call.py", line 290, in __await__
#     raise _create_rpc_error(self._cython_call._initial_metadata,
# grpc.aio._call.AioRpcError: <AioRpcError of RPC that terminated with:
# 	status = StatusCode.CANCELLED
# 	details = "CANCELLED"
# 	debug_error_string = "UNKNOWN:Error received from peer ipv4:172.25.0.1:50055 {grpc_message:"CANCELLED", grpc_status:1, created_time:"2023-05-29T22:34:18.155919086-06:00"}"
# >
