# %%
# Importing necessary libraries

from reachy_sdk_modified import ReachySDK
import numpy as np

from reachy_sdk_modified.trajectory import goto_compliant
from reachy_sdk_modified.trajectory import InterpolationMode
import time

# %%
# Only needed for simulation

import subprocess

# %%
def happy_antennas():
    for _ in range(7):
        reachy.head.l_antenna.goal_position = 30.0
        reachy.head.r_antenna.goal_position = -30.0

        time.sleep(0.2)

        reachy.head.l_antenna.goal_position = -30.0
        reachy.head.r_antenna.goal_position = 30.0

        time.sleep(0.2)

    reachy.head.l_antenna.goal_position = 0.0
    reachy.head.r_antenna.goal_position = 0.0

# %%
def hello_left_arm():
    left_arm_hello_position = {
    reachy.l_arm.l_shoulder_pitch: 0,
    reachy.l_arm.l_shoulder_roll: 50,
    reachy.l_arm.l_arm_yaw: 70,
    reachy.l_arm.l_elbow_pitch: -120,
    reachy.l_arm.l_forearm_yaw: 80,
    reachy.l_arm.l_wrist_pitch: 0,
    reachy.l_arm.l_wrist_roll: -40,
    }

    left_arm_base_position = {
    reachy.l_arm.l_shoulder_pitch: 0,
    reachy.l_arm.l_shoulder_roll: 0,
    reachy.l_arm.l_arm_yaw: 0,
    reachy.l_arm.l_elbow_pitch: 0,
    reachy.l_arm.l_forearm_yaw: 0,
    reachy.l_arm.l_wrist_pitch: 0,
    reachy.l_arm.l_wrist_roll: 0,
    }
    
    # The 'goto_compliant' function is exactly like the goto function, except it takes two additional inputs
    
    goto_compliant(
    goal_positions = left_arm_hello_position,
    damping_matrix = np.identity(len(left_arm_hello_position)),
    stiffness_matrix = np.identity(len(left_arm_hello_position)),
    duration = 5,
    interpolation_mode = InterpolationMode.MINIMUM_JERK
    )

    for _ in range(3):
        goto_compliant(
          goal_positions = {reachy.l_arm.l_wrist_roll: 20.0},
          damping_matrix = np.identity(1),
          stiffness_matrix = np.identity(1),
          duration = 1.5,
          interpolation_mode = InterpolationMode.LINEAR
        )
        goto_compliant(
          goal_positions = {reachy.l_arm.l_wrist_roll: -40.0},
          damping_matrix = np.identity(1),
          stiffness_matrix = np.identity(1),
          duration = 1.5,
          interpolation_mode = InterpolationMode.LINEAR
        )

    time.sleep(0.2)

    goto_compliant(
    goal_positions = left_arm_base_position,
    damping_matrix = np.identity(len(left_arm_base_position)),
    stiffness_matrix = np.identity(len(left_arm_base_position)),
    duration = 5,
    interpolation_mode = InterpolationMode.LINEAR
    )

# %%
def move_head():
    reachy.head.look_at(0.5, -0.3, -0.1, duration=1.0)
    time.sleep(0.3)
    reachy.head.look_at(0.5, 0.3, -0.1, duration=1.0)
    time.sleep(0.3)
    reachy.head.look_at(0.5, 0, -0.1, duration=1.0)
    time.sleep(0.3)
    
    head_tilted_position = {
    reachy.head.neck_roll: -20,
    reachy.head.neck_pitch: 0,
    reachy.head.neck_yaw:0,
    }
    
    goto_compliant(
    damping_matrix = np.identity(len(head_tilted_position)),
    stiffness_matrix = np.identity(len(head_tilted_position)),
    goal_positions = head_tilted_position,
    duration = 1,
    interpolation_mode = InterpolationMode.MINIMUM_JERK
    )

# %%
def say_hello():
    #move_head()
    happy_antennas()
    hello_left_arm()
    #reachy.head.look_at(0.5, 0, 0, duration=0.5)

# %%
def get_localhost_wsl():
    result = subprocess.check_output("cat /etc/resolv.conf | grep nameserver | awk '{ print $2 }'", shell=True, text=True)
    result = result[:-1]
    print(result)
    return result

# %%
# First, run Windows Powershell as an administrator, and run the following command:
# New-NetFirewallRule -DisplayName "WSL" -Direction Inbound  -InterfaceAlias "vEthernet (WSL)"  -Action Allow
# reachy = ReachySDK(host='localhost') # replace with correct IP if the simulation is not on your computer
# reachy = ReachySDK(host='Acer-Nitro-5.local') # Find IP in WSL by running 'ip route' command in the terminal, and looking for the 'default via' value
  
ip_address = get_localhost_wsl()
reachy = ReachySDK(host=ip_address) # Find IP in WSL by running 'ip route' command in the terminal, and looking for the 'default via' value
say_hello()
# Out:
# 172.20.0.1
# Entering goto function for modified library
# Goal Positions:  {<Joint name="l_shoulder_pitch" pos="0.00" mode="stiff">: 0, <Joint name="l_shoulder_roll" pos="0.04" mode="stiff">: 50, <Joint name="l_arm_yaw" pos="0.00" mode="stiff">: 70, <Joint name="l_elbow_pitch" pos="-0.00" mode="stiff">: -120, <Joint name="l_forearm_yaw" pos="0.00" mode="stiff">: 80, <Joint name="l_wrist_pitch" pos="-0.00" mode="stiff">: 0, <Joint name="l_wrist_roll" pos="-0.03" mode="stiff">: -40}
# Goal Positions Keys:  [<Joint name="l_shoulder_pitch" pos="0.00" mode="stiff">, <Joint name="l_shoulder_roll" pos="0.04" mode="stiff">, <Joint name="l_arm_yaw" pos="0.00" mode="stiff">, <Joint name="l_elbow_pitch" pos="-0.00" mode="stiff">, <Joint name="l_forearm_yaw" pos="0.00" mode="stiff">, <Joint name="l_wrist_pitch" pos="-0.00" mode="stiff">, <Joint name="l_wrist_roll" pos="-0.03" mode="stiff">]
# Joint List:  ['l_shoulder_pitch', 'l_shoulder_roll', 'l_arm_yaw', 'l_elbow_pitch', 'l_forearm_yaw', 'l_wrist_pitch', 'l_wrist_roll']
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Breaking
# elapsed_time 4.408678770065308
# Goal Positions [   0   50   70 -120   80    0  -40]
# Final Position:  [ 3.0000e-02  5.4470e+01  6.9440e+01 -1.1897e+02  8.3490e+01  2.9900e+00
#  -3.9760e+01]
# Error:  4.469999999999999
# Change:  0.0
#
# Entering goto function for modified library
# Goal Positions:  {<Joint name="l_wrist_roll" pos="-39.76" mode="stiff">: 20.0}
# Goal Positions Keys:  [<Joint name="l_wrist_roll" pos="-39.76" mode="stiff">]
# Joint List:  ['l_wrist_roll']
# Breaking
# elapsed_time 1.4744012355804443
# Goal Positions [20.]
# Final Position:  [15.02]
# Error:  4.98
# Change:  0.0
#
# Entering goto function for modified library
# Goal Positions:  {<Joint name="l_wrist_roll" pos="15.02" mode="stiff">: -40.0}
# Goal Positions Keys:  [<Joint name="l_wrist_roll" pos="15.02" mode="stiff">]
# Joint List:  ['l_wrist_roll']
# Breaking
# elapsed_time 1.4758117198944092
# Goal Positions [-40.]
# Final Position:  [-35.01]
# Error:  4.990000000000002
# Change:  0.0
#
# Entering goto function for modified library
# Goal Positions:  {<Joint name="l_wrist_roll" pos="-35.01" mode="stiff">: 20.0}
# Goal Positions Keys:  [<Joint name="l_wrist_roll" pos="-35.01" mode="stiff">]
# Joint List:  ['l_wrist_roll']
# Breaking
# elapsed_time 1.5054433345794678
# Goal Positions [20.]
# Final Position:  [16.37]
# Error:  3.629999999999999
# Change:  0.0
#
# Entering goto function for modified library
# Goal Positions:  {<Joint name="l_wrist_roll" pos="17.09" mode="stiff">: -40.0}
# Goal Positions Keys:  [<Joint name="l_wrist_roll" pos="17.09" mode="stiff">]
# Joint List:  ['l_wrist_roll']
# Breaking
# elapsed_time 1.4878530502319336
# Goal Positions [-40.]
# Final Position:  [-35.34]
# Error:  4.659999999999997
# Change:  0.0
#
# Entering goto function for modified library
# Goal Positions:  {<Joint name="l_wrist_roll" pos="-35.34" mode="stiff">: 20.0}
# Goal Positions Keys:  [<Joint name="l_wrist_roll" pos="-35.34" mode="stiff">]
# Joint List:  ['l_wrist_roll']
# Breaking
# elapsed_time 1.494926929473877
# Goal Positions [20.]
# Final Position:  [15.61]
# Error:  4.390000000000001
# Change:  0.0
#
# Entering goto function for modified library
# Goal Positions:  {<Joint name="l_wrist_roll" pos="15.61" mode="stiff">: -40.0}
# Goal Positions Keys:  [<Joint name="l_wrist_roll" pos="15.61" mode="stiff">]
# Joint List:  ['l_wrist_roll']
# Breaking
# elapsed_time 1.506519079208374
# Goal Positions [-40.]
# Final Position:  [-35.92]
# Error:  4.079999999999998
# Change:  0.0
#
# Entering goto function for modified library
# Goal Positions:  {<Joint name="l_shoulder_pitch" pos="0.01" mode="stiff">: 0, <Joint name="l_shoulder_roll" pos="53.44" mode="stiff">: 0, <Joint name="l_arm_yaw" pos="69.67" mode="stiff">: 0, <Joint name="l_elbow_pitch" pos="-119.30" mode="stiff">: 0, <Joint name="l_forearm_yaw" pos="82.85" mode="stiff">: 0, <Joint name="l_wrist_pitch" pos="2.50" mode="stiff">: 0, <Joint name="l_wrist_roll" pos="-39.75" mode="stiff">: 0}
# Goal Positions Keys:  [<Joint name="l_shoulder_pitch" pos="0.01" mode="stiff">, <Joint name="l_shoulder_roll" pos="53.44" mode="stiff">, <Joint name="l_arm_yaw" pos="69.67" mode="stiff">, <Joint name="l_elbow_pitch" pos="-119.30" mode="stiff">, <Joint name="l_forearm_yaw" pos="82.85" mode="stiff">, <Joint name="l_wrist_pitch" pos="2.50" mode="stiff">, <Joint name="l_wrist_roll" pos="-39.75" mode="stiff">]
# Joint List:  ['l_shoulder_pitch', 'l_shoulder_roll', 'l_arm_yaw', 'l_elbow_pitch', 'l_forearm_yaw', 'l_wrist_pitch', 'l_wrist_roll']
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Torque Detected
# Breaking
# elapsed_time 5.0275444984436035
# Goal Positions [0 0 0 0 0 0 0]
# Final Position:  [ 0.17  4.25  0.53 -0.69  3.74  2.06 -0.28]
# Error:  4.25
# Change:  0.0
